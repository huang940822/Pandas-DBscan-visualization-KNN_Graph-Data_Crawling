# %% [markdown]
# # 作業二：MLB 資料視覺化
#
# ## 作業要求：
# * 使用提供的 .ipynb 模板
# * 計算所有大聯盟球員的平均得分（Runs）將球員分為「高得分」與「低得分」兩組
# * 將兩組球員的 *得分指標（如下）* 全部相加 畫出這兩組的 correlation matrix
# * 解釋你對結果的看法
#
# ## 得分指標
# * 得分（Runs Scored, R）
# * 打點（Runs Batted In, RBI）
# * 安打數（Hits, H）
# * 全壘打數（Home Runs, HR）
# * 打擊率（Batting Average, AVG）
# * 上壘率（On-Base Percentage, OBP）
# * 長打率（Slugging Percentage, SLG）
# * 盜壘數（Stolen Bases, SB）
# * 打數（At Bats, AB）
# * 四壞球率（Walks, BB）
# * 被三振數（Strikeouts, K）

# %% [markdown]
# ## 引入套件
# 這份作業會使用：
# * [pandas](https://pandas.pydata.org/)
# * [seaborn](https://seaborn.pydata.org/)
# * [matplotlib](https://matplotlib.org/)

# %%
## TODO 1: 引入需使用的套件
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## 讀取檔案
# 使用 pandas 讀入 csv 檔，成為 dataframe

# %%
## TODO 2: 讀取檔案

# 讀取你的檔案
mlb_df = pd.read_csv("output.csv")

# 檢查
mlb_df.head
# Out:
# <bound method NDFrame.head of     AB    AVG  BB  G  H  HR    OBP                                 PLAYER  R  \
# 0   14  0.643   3  4  9   3  0.722        1FernandoF Tatis Jr.TatisRF1‌‌‌  7
# 1    5  0.400   4  2  2   1  0.667             2BryceB HarperHarper1B2‌‌‌  2
# 2    8  0.625   0  2  5   1  0.625        3MichaelM Harris IIHarrisCF3‌‌‌  2
# 3   11  0.364   1  4  4   3  0.385       4KyleK HigashiokaHigashiokaC4‌‌‌  3
# 4   11  0.455   1  3  5   2  0.500         5JacksonJ ChourioChourioLF5‌‌‌  3
# ..  ..    ...  .. .. ..  ..    ...                                    ... ..
# 91   8  0.000   0  2  0   0  0.000       91RamónR LaureanoLaureanoLF91‌‌‌  0
# 92   8  0.000   0  2  0   0  0.000           91BrandonB MarshMarshLF91‌‌‌  0
# 93   7  0.000   0  2  0   0  0.000  91RyanR MountcastleMountcastle1B91‌‌‌  0
# 94  11  0.000   0  3  0   0  0.000              91JoeyJ OrtizOrtiz3B91‌‌‌  0
# 95   6  0.000   0  2  0   0  0.000           91GioG UrshelaUrshela3B91‌‌‌  0
#
#     RBI  SB    SLG  SO TEAM
# 0     5   0  1.429   0   SD
# 1     2   0  1.200   3  PHI
# 2     2   0  1.125   1  ATL
# 3     4   0  1.273   0   SD
# 4     3   1  1.000   1  MIL
# ..  ...  ..    ...  ..  ...
# 91    0   0  0.000   4  ATL
# 92    0   0  0.000   1  PHI
# 93    0   0  0.000   4  BAL
# 94    0   0  0.000   2  MIL
# 95    0   0  0.000   2  ATL
#
# [96 rows x 14 columns]>

# %% [markdown]
# ## 處理資料
# 在這步驟，我們要先計算所有球員的平均得分，從而將球員分成高得分組與低得分組

# %%
# TODO 3: 處理資料

# 計算所有球員 Runs 的平均值
R_mean = mlb_df['R'].mean()

# 將球員分成得分高於平和低於平均兩組
above_avg_df = mlb_df[mlb_df['R'] > R_mean]
below_avg_df = mlb_df[mlb_df['R'] <= R_mean]

# %% [markdown]
# ## 資料視覺化
# 我們要分別對上面兩 dataframe 算出 [correlation matrix](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.corr.html)，並使用 [heatmap](https://seaborn.pydata.org/generated/seaborn.heatmap.html) 為其視覺化

# %%
# TODO 4: 資料視覺化

# 要計算的欄位
numeric_cols = ['AB','AVG','BB','H','HR','OBP','R','RBI','SB','SLG','SO']

# 計算 correlation matrix
above_avg_cor_matrix = above_avg_df[numeric_cols].corr()
below_avg_cor_matrix = below_avg_df[numeric_cols].corr()

# 請將兩張圖娉排顯示。左邊是高得分組的 heatmap，右邊是低得分組
plt.figure(figsize=(20, 8))

plt.subplot(1,2,1)#子圖1位置
#高得分組的heatmap
sns.heatmap(above_avg_cor_matrix, annot=True, cmap='coolwarm', fmt='.2f', cbar=True)
plt.title('Correlation Matrix of High Runs Group', fontsize=16)

plt.subplot(1,2,2)#子圖2位置
#低得分組的heatmap
sns.heatmap(below_avg_cor_matrix, annot=True, cmap='coolwarm', fmt='.2f', cbar=True)
plt.title('Correlation Matrix of Low Runs Group', fontsize=16)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 你的解讀
# 請回下列問題（直接將回答寫在這個 cell）
#
# ### Q1: 影響「高得分組」球員得分（Runs, R）較多的得分指標，和影響影響「低得分組」較多的指標一樣嗎？
# TODO 5
# <p>不一樣
#
# ### Q2: 從這兩者的差距中，你觀察到了什麼、會如何解讀這樣的差距呢？（例如，你能說出影響球員是否會成為高得分球員的關鍵因素嗎？）
# TODO 6
# <p>在高分組裡，高的AVG表示球員有更多機會上壘，而OBP高也意味著得分機會更多
# <p>HR可以直接提高得分，在高分組裡通常HR較高
#
# <p>低分組裡，AB較低表示打擊機會較少，進而得分降低
# <p>SO高的球員顯現出上壘機會少，得分也就更少
